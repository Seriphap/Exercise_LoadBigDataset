# %% [markdown]
# <a href="https://colab.research.google.com/github/Seriphap/Exercise_LoadBigDataset/blob/main/HW_3_2_LoadingBigDataset_6710422002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download CSV file into Dataframe

# %%
# @title
# !pip install gdown

# %%
# @title
import dask.dataframe as dd
import gdown

file_id = '1njGRC9gjmnbi9qGLmzRQj4MyMyPDHp1h'
url = f'https://drive.google.com/uc?id={file_id}'

# Download the file
gdown.download(url, '/content/downloaded_file.csv', quiet=False)

# Read CSV with Dask
df = dd.read_csv('/content/downloaded_file.csv')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1njGRC9gjmnbi9qGLmzRQj4MyMyPDHp1h
# From (redirected): https://drive.google.com/uc?id=1njGRC9gjmnbi9qGLmzRQj4MyMyPDHp1h&confirm=t&uuid=8fe817ec-891b-4d4c-8505-81b8b32f7d13
# To: /content/downloaded_file.csv
# 100%|██████████| 3.04G/3.04G [00:33<00:00, 90.2MB/s]

# %% [markdown]
# # 2. Show the data information

# %%
# @title
display(df.info())
#display(df.columns)
display(df.dtypes) # Display column data types (metadata)
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 19 entries, case_id to subjectroles_name_838M
# dtypes: float64(10), int64(3), string(6)
# None
# case_id                                      int64
# collater_typofvalofguarant_298M    string[pyarrow]
# collater_typofvalofguarant_407M    string[pyarrow]
# collater_valueofguarantee_1124L            float64
# collater_valueofguarantee_876L             float64
# collaterals_typeofguarante_359M    string[pyarrow]
# collaterals_typeofguarante_669M    string[pyarrow]
# num_group1                                   int64
# num_group2                                   int64
# pmts_dpd_1073P                             float64
# pmts_dpd_303P                              float64
# pmts_month_158T                            float64
# pmts_month_706T                            float64
# pmts_overdue_1140A                         float64
# pmts_overdue_1152A                         float64
# pmts_year_1139T                            float64
# ...

# %% [markdown]
# # Example Data (10 Rows)

# %%
# @title
display(df.head(10))
#display(df.tail())#last rows from the last partition
num_rows = len(df.compute())
print(f"Number of rows: {num_rows}")
# Out:
#    case_id collater_typofvalofguarant_298M collater_typofvalofguarant_407M  \
# 0    36830                        9a0c095e                        8fd95e4b
# 1    36830                        8fd95e4b                        8fd95e4b
# 2    36830                        9a0c095e                        a55475b1
# 3    36830                        8fd95e4b                        a55475b1
# 4    36830                        9a0c095e                        a55475b1
# 5    36830                        a55475b1                        a55475b1
# 6    36830                        a55475b1                        a55475b1
# 7    36830                        a55475b1                        a55475b1
# 8    36830                        a55475b1                        a55475b1
# 9    36830                        a55475b1                        a55475b1
#
#    collater_valueofguarantee_1124L  collater_valueofguarantee_876L  \
# 0                              0.0                             0.0
# ...

# %% [markdown]
# # Summary Statistics of Data

# %%
# @title
#Show summary statistics (like describe in pandas)
print("\nSummary statistics:")
display(df.describe().compute())  # Trigger computation with compute()
# Out:
# Summary statistics:
#             case_id  collater_valueofguarantee_1124L  \
# count  3.305376e+07                     4.701760e+05
# mean   1.457855e+06                     1.044418e+07
# std    6.574535e+05                     2.797464e+08
# min    3.683000e+04                     0.000000e+00
# 25%    9.153400e+05                     0.000000e+00
# 50%    1.665535e+06                     0.000000e+00
# 75%    1.715827e+06                     0.000000e+00
# max    2.658153e+06                     1.875996e+10
#
#        collater_valueofguarantee_876L    num_group1    num_group2  \
# count                    1.327778e+06  3.305376e+07  3.305376e+07
# mean                     4.160212e+06  4.701797e+00  1.320155e+01
# std                      1.537820e+08  6.427977e+00  9.278773e+00
# min                      0.000000e+00  0.000000e+00  0.000000e+00
# 25%                      0.000000e+00  1.000000e+00  6.000000e+00
# ...
